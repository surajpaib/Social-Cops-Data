# %%
% matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn

# %%
data = pd.read_csv('dhamagaon.csv')

# %%
data.head(10)
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>Number</th>
#       <th>Metric</th>
#       <th>April</th>
#       <th>May</th>
#       <th>June</th>
#       <th>July</th>
#       <th>August</th>
#       <th>September</th>
#       <th>October</th>
#       <th>November</th>
#       <th>December</th>
#       <th>January</th>
#       <th>February</th>
#       <th>March</th>
#       <th>Total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>8</td>
#       <td>1.1</td>
#       <td>Total number of pregnant women Registered for ...</td>
#       <td>1</td>
#       <td>2</td>
#       <td>2</td>
#       <td>2</td>
#       <td>2</td>
#       <td>3</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>2</td>
#       <td>1</td>
#       <td>0</td>
#       <td>18</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>9</td>
# ...

# %%
x =[]
for d in range(3,15):
    x.append(data.ix[1][d])

# %%
print x
# Out:
# [1, 2, 2, 2, 2, 3, 1, 1, 1, 2, 1, 0]

# %%
seaborn.distplot(x)
